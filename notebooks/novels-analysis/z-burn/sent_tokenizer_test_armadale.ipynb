# %%
### USEFUL:
### https://www.holisticseo.digital/python-seo/nltk/tokenization
###

# %%
novel_to_analyze = 'Armadale.txt'

# %%
import codecs
import os
import pandas as pd
# to be able to see more columns when dataframes are printed out:
pd.set_option('display.max_columns', 100)
# to not get copy warnings when splitting dataframes
pd.options.mode.chained_assignment = None
import re
import spacy
import sys
import numpy as np
import matplotlib.pyplot as plt
import random
from nltk.tokenize import sent_tokenize

# %%
## to Newpaper Novel corpus:
path_to_nnovels_corpus = '../../data/corpora/corpus_newspaper_novels/' 

## to assets:
path_to_assets = '../../assets/'
## characters and numbers to exclude from texts:
exclude_file = 'characters_and_numbers_to_exclude.txt'

# characters to exclude
with codecs.open(path_to_assets + exclude_file, 'r', encoding='utf-8', errors="ignore") as characters_to_exclude_raw:
    characters_to_exclude = characters_to_exclude_raw.read()
    characters_to_exclude = characters_to_exclude.split()

# %%
with codecs.open(path_to_nnovels_corpus + novel_to_analyze, 'r', encoding='utf-8', errors="ignore") as raw_text:
    dirty_text = raw_text.read()

split_on = ["END OF THE PROJECT GUTENBERG","End of the Project Gutenberg EBook","End of Project Gutenberg","End of The Project Gutenberg"] 
for text in split_on:
    dirty_text = dirty_text.split(text)[0]
prefixes = "(Mr|St|Mrs|Ms|Dr)[.]"
newline_chars = "(\n|\r)"
clean_text_string = re.sub(prefixes,"\\1<prd>", dirty_text)
# clean_text_string = re.sub('[“”]', '"', clean_text_string)
clean_text_string = re.sub('(“|”|”)', '"', clean_text_string)
clean_text_list = sent_tokenize(clean_text_string)

clean_sentences = []
for sent in clean_text_list:
    # res.append(re.sub('\n', '', sent))
    clean_sent = re.sub('\n', ' ', sent)
    clean_sent = re.sub('\r', ' ', clean_sent)
    clean_sent = re.sub('\s+',' ', clean_sent)
    clean_sentences.append(clean_sent)
    
# print(len(clean_text))
# print(clean_text[:10])
# print(len(clean_sentences))
# print(clean_sentences[:10])

# %%
print(len(clean_sentences))
for position, sent in enumerate(clean_sentences):
    print(position, end=': ')
    print(sent)
    if position == 50:
        break
# Out:
# 16582
# 0: ﻿THE TRAVELERS.
# 1: It was the opening of the season of eighteen hundred and thirty-two, at the Baths of Wildbad.
# 2: The evening shadows were beginning to gather over the quiet little German town, and the diligence was expected every minute.
# 3: Before the door of the principal inn, waiting the arrival of the first visitors of the year, were assembled the three notable personages of Wildbad, accompanied by their wives--the mayor, representing the inhabitants; the doctor, representing the waters; the landlord, representing his own establishment.
# 4: Beyond this select circle, grouped snugly about the trim little square in front of the inn, appeared the towns-people in general, mixed here and there with the country people, in their quaint German costume, placidly expectant of the diligence--the men in short black jackets, tight black breeches, and three-cornered beaver hats; the women with their long light hair hanging in one thickly plaited tail behind them, and the waists of their short woolen gowns inserted modestly in the region of their shoulder-blades.
# 5: Round the outer edge of the assemblage thus formed, flying detachments of plump white-headed children careered in perpetual motion; while, mysteriously apart from the rest of the inhabitants, the musicians of the Baths stood collected in one lost corner, waiting the appearance of the first visitors to play the first tune of the season in the form of a serenade.
# 6: The light of a May evening was still bright on the tops of the great wooded hills watching high over the town on the right hand and the left; and the cool breeze that comes before sunset came keenly fragrant here with the balsamic odor of the first of the Black Forest.
# 7: "Mr<prd> Landlord," said the mayor’s wife (giving the landlord his title), "have you any foreign guests coming on this first day of the season?"
# 8: "Madame Mayoress," replied the landlord (returning the compliment), "I have two.
# 9: They have written--the one by the hand of his servant, the other by his own hand apparently--to order their rooms; and they are from England, both, as I think by their names.
# 10: If you ask me to pronounce those names, my tongue hesitates; if you ask me to spell them, here they are, letter by letter, first and second in their order as they come.
# 11: First, a high-born stranger (by title Mister) who introduces himself in eight letters, A, r, m, a, d, a, l, e--and comes ill in his own carriage.
# 12: Second, a high-born stranger (by title Mister also), who introduces himself in four letters--N, e, a, l--and comes ill in the diligence.
# 13: His excellency of the eight letters writes to me (by his servant) in French; his excellency of the four letters writes to me in German.
# 14: The rooms of both are ready.
# 15: I know no more."
# 16: "Perhaps," suggested the mayor’s wife, "Mr<prd> Doctor has heard from one or both of these illustrious strangers?"
# 17: "From one only, Madam Mayoress; but not, strictly speaking, from the person himself.
# 18: I have received a medical report of his excellency of the eight letters, and his case seems a bad one.
# 19: God help him!"
# 20: "The diligence!"
# 21: cried a child from the outskirts of the crowd.
# 22: The musicians seized their instruments, and silence fell on the whole community.
# 23: From far away in the windings of the forest gorge, the ring of horses’ bells came faintly clear through the evening stillness.
# 24: Which carriage was approaching--the private carriage with Mr<prd> Armadale, or the public carriage with Mr<prd> Neal?
# 25: "Play, my friends!"
# 26: cried the mayor to the musicians.
# 27: "Public or private, here are the first sick people of the season.
# 28: Let them find us cheerful."
# 29: The band played a lively dance tune, and the children in the square footed it merrily to the music.
# 30: At the same moment, their elders near the inn door drew aside, and disclosed the first shadow of gloom that fell over the gayety and beauty of the scene.
# 31: Through the opening made on either hand, a little procession of stout country girls advanced, each drawing after her an empty chair on wheels; each in waiting (and knitting while she waited) for the paralyzed wretches who came helpless by hundreds then--who come helpless by thousands now--to the waters of Wildbad for relief.
# 32: While the band played, while the children danced, while the buzz of many talkers deepened, while the strong young nurses of the coming cripples knitted impenetrably, a woman’s insatiable curiosity about other women asserted itself in the mayor’s wife.
# 33: She drew the landlady aside, and whispered a question to her on the spot.
# 34: "A word more, ma’am," said the mayor’s wife, "about the two strangers from England.
# 35: Are their letters explicit?
# 36: Have they got any ladies with them?"
# 37: "The one by the diligence--no," replied the landlady.
# 38: "But the one by the private carriage--yes.
# 39: He comes with a child; he comes with a nurse; and," concluded the landlady, skillfully keeping the main point of interest till the last, "he comes with a Wife."
# 40: The mayoress brightened; the doctoress (assisting at the conference) brightened; the landlady nodded significantly.
# 41: In the minds of all three the same thought started into life at the same moment--"We shall see the Fashions!"
# 42: In a minute more, there was a sudden movement in the crowd; and a chorus of voices proclaimed that the travelers were at hand.
# 43: By this time the coming vehicle was in sight, and all further doubt was at an end.
# 44: It was the diligence that now approached by the long street leading into the square--the diligence (in a dazzling new coat of yellow paint) that delivered the first visitors of the season at the inn door.
# 45: Of the ten travelers released from the middle compartment and the back compartment of the carriage--all from various parts of Germany--three were lifted out helpless, and were placed in the chairs on wheels to be drawn to their lodgings in the town.
# 46: The front compartment contained two passengers only--Mr<prd> Neal and his traveling servant.
# 47: With an arm on either side to assist him, the stranger (whose malady appeared to be locally confined to a lameness in one of his feet) succeeded in descending the steps of the carriage easily enough.
# 48: While he steadied himself on the pavement by the help of his stick--looking not over-patiently toward the musicians who were serenading him with the waltz in "Der Freischutz"--his personal appearance rather damped the enthusiasm of the friendly little circle assembled to welcome him.
# 49: He was a lean, tall, serious, middle-aged man, with a cold gray eye and a long upper lip, with overhanging eyebrows and high cheek-bones; a man who looked what he was--every inch a Scotchman.
# 50: "Where is the proprietor of this hotel?"

# %%
processed_sentences = []
temp_list_dialogue = []
temp_list_narration = []
dialogue_started = False


for sent in clean_sentences:
    if sent.startswith('"'):
        dialogue_started = True

    if dialogue_started:
        temp_list_dialogue.append(sent)
        
        if sent.endswith('"'):
            processed_sentences.append(['DIALOGUE', temp_list_dialogue])
            temp_list_dialogue = []
            dialogue_started = False
        else:
            continue
    else:
        temp_list_narration.append(sent)
        processed_sentences.append(['NARRATION', temp_list_narration])
        temp_list_narration = []
        
# print(processed_sentences[:50])

# %%
for position, sent in enumerate(processed_sentences):
    print(position, end=': ')
    print(sent)
    if position == 50:
        break
# Out:
# 0: ['NARRATION', ['\ufeffTHE TRAVELERS.']]
# 1: ['NARRATION', ['It was the opening of the season of eighteen hundred and thirty-two, at the Baths of Wildbad.']]
# 2: ['NARRATION', ['The evening shadows were beginning to gather over the quiet little German town, and the diligence was expected every minute.']]
# 3: ['NARRATION', ['Before the door of the principal inn, waiting the arrival of the first visitors of the year, were assembled the three notable personages of Wildbad, accompanied by their wives--the mayor, representing the inhabitants; the doctor, representing the waters; the landlord, representing his own establishment.']]
# 4: ['NARRATION', ['Beyond this select circle, grouped snugly about the trim little square in front of the inn, appeared the towns-people in general, mixed here and there with the country people, in their quaint German costume, placidly expectant of the diligence--the men in short black jackets, tight black breeches, and three-cornered beaver hats; the women with their long light hair hanging in one thickly plaited tail behind them, and the waists of their short woolen gowns inserted modestly in the region of their shoulder-blades.']]
# 5: ['NARRATION', ['Round the outer edge of the assemblage thus formed, flying detachments of plump white-headed children careered in perpetual motion; while, mysteriously apart from the rest of the inhabitants, the musicians of the Baths stood collected in one lost corner, waiting the appearance of the first visitors to play the first tune of the season in the form of a serenade.']]
# 6: ['NARRATION', ['The light of a May evening was still bright on the tops of the great wooded hills watching high over the town on the right hand and the left; and the cool breeze that comes before sunset came keenly fragrant here with the balsamic odor of the first of the Black Forest.']]
# 7: ['DIALOGUE', ['"Mr<prd> Landlord," said the mayor’s wife (giving the landlord his title), "have you any foreign guests coming on this first day of the season?"']]
# 8: ['DIALOGUE', ['"Madame Mayoress," replied the landlord (returning the compliment), "I have two.', 'They have written--the one by the hand of his servant, the other by his own hand apparently--to order their rooms; and they are from England, both, as I think by their names.', 'If you ask me to pronounce those names, my tongue hesitates; if you ask me to spell them, here they are, letter by letter, first and second in their order as they come.', 'First, a high-born stranger (by title Mister) who introduces himself in eight letters, A, r, m, a, d, a, l, e--and comes ill in his own carriage.', 'Second, a high-born stranger (by title Mister also), who introduces himself in four letters--N, e, a, l--and comes ill in the diligence.', 'His excellency of the eight letters writes to me (by his servant) in French; his excellency of the four letters writes to me in German.', 'The rooms of both are ready.', 'I know no more."']]
# 9: ['DIALOGUE', ['"Perhaps," suggested the mayor’s wife, "Mr<prd> Doctor has heard from one or both of these illustrious strangers?"']]
# 10: ['DIALOGUE', ['"From one only, Madam Mayoress; but not, strictly speaking, from the person himself.', 'I have received a medical report of his excellency of the eight letters, and his case seems a bad one.', 'God help him!"']]
# 11: ['DIALOGUE', ['"The diligence!"']]
# 12: ['NARRATION', ['cried a child from the outskirts of the crowd.']]
# 13: ['NARRATION', ['The musicians seized their instruments, and silence fell on the whole community.']]
# 14: ['NARRATION', ['From far away in the windings of the forest gorge, the ring of horses’ bells came faintly clear through the evening stillness.']]
# 15: ['NARRATION', ['Which carriage was approaching--the private carriage with Mr<prd> Armadale, or the public carriage with Mr<prd> Neal?']]
# 16: ['DIALOGUE', ['"Play, my friends!"']]
# 17: ['NARRATION', ['cried the mayor to the musicians.']]
# 18: ['DIALOGUE', ['"Public or private, here are the first sick people of the season.', 'Let them find us cheerful."']]
# 19: ['NARRATION', ['The band played a lively dance tune, and the children in the square footed it merrily to the music.']]
# 20: ['NARRATION', ['At the same moment, their elders near the inn door drew aside, and disclosed the first shadow of gloom that fell over the gayety and beauty of the scene.']]
# 21: ['NARRATION', ['Through the opening made on either hand, a little procession of stout country girls advanced, each drawing after her an empty chair on wheels; each in waiting (and knitting while she waited) for the paralyzed wretches who came helpless by hundreds then--who come helpless by thousands now--to the waters of Wildbad for relief.']]
# 22: ['NARRATION', ['While the band played, while the children danced, while the buzz of many talkers deepened, while the strong young nurses of the coming cripples knitted impenetrably, a woman’s insatiable curiosity about other women asserted itself in the mayor’s wife.']]
# 23: ['NARRATION', ['She drew the landlady aside, and whispered a question to her on the spot.']]
# 24: ['DIALOGUE', ['"A word more, ma’am," said the mayor’s wife, "about the two strangers from England.', 'Are their letters explicit?', 'Have they got any ladies with them?"']]
# 25: ['DIALOGUE', ['"The one by the diligence--no," replied the landlady.', '"But the one by the private carriage--yes.', 'He comes with a child; he comes with a nurse; and," concluded the landlady, skillfully keeping the main point of interest till the last, "he comes with a Wife."']]
# 26: ['NARRATION', ['The mayoress brightened; the doctoress (assisting at the conference) brightened; the landlady nodded significantly.']]
# 27: ['NARRATION', ['In the minds of all three the same thought started into life at the same moment--"We shall see the Fashions!"']]
# 28: ['NARRATION', ['In a minute more, there was a sudden movement in the crowd; and a chorus of voices proclaimed that the travelers were at hand.']]
# 29: ['NARRATION', ['By this time the coming vehicle was in sight, and all further doubt was at an end.']]
# 30: ['NARRATION', ['It was the diligence that now approached by the long street leading into the square--the diligence (in a dazzling new coat of yellow paint) that delivered the first visitors of the season at the inn door.']]
# 31: ['NARRATION', ['Of the ten travelers released from the middle compartment and the back compartment of the carriage--all from various parts of Germany--three were lifted out helpless, and were placed in the chairs on wheels to be drawn to their lodgings in the town.']]
# 32: ['NARRATION', ['The front compartment contained two passengers only--Mr<prd> Neal and his traveling servant.']]
# 33: ['NARRATION', ['With an arm on either side to assist him, the stranger (whose malady appeared to be locally confined to a lameness in one of his feet) succeeded in descending the steps of the carriage easily enough.']]
# 34: ['NARRATION', ['While he steadied himself on the pavement by the help of his stick--looking not over-patiently toward the musicians who were serenading him with the waltz in "Der Freischutz"--his personal appearance rather damped the enthusiasm of the friendly little circle assembled to welcome him.']]
# 35: ['NARRATION', ['He was a lean, tall, serious, middle-aged man, with a cold gray eye and a long upper lip, with overhanging eyebrows and high cheek-bones; a man who looked what he was--every inch a Scotchman.']]
# 36: ['DIALOGUE', ['"Where is the proprietor of this hotel?"']]
# 37: ['NARRATION', ['he asked, speaking in the German language, with a fluent readiness of expression, and an icy coldness of manner.']]
# 38: ['DIALOGUE', ['"Fetch the doctor," he continued, when the landlord had presented himself, "I want to see him immediately."']]
# 39: ['DIALOGUE', ['"I am here already, sir," said the doctor, advancing from the circle of friends, "and my services are entirely at your disposal."']]
# 40: ['DIALOGUE', ['"Thank you," said Mr<prd> Neal, looking at the doctor, as the rest of us look at a dog when we have whistled and the dog has come.', '"I shall be glad to consult you to-morrow morning, at ten o’clock, about my own case.', 'I only want to trouble you now with a message which I have undertaken to deliver.', 'We overtook a traveling carriage on the road here with a gentleman in it--an Englishman, I believe--who appeared to be seriously ill. A lady who was with him begged me to see you immediately on my arrival, and to secure your professional assistance in removing the patient from the carriage.', 'Their courier has met with an accident, and has been left behind on the road, and they are obliged to travel very slowly.', 'If you are here in an hour, you will be here in time to receive them.', 'That is the message.', 'Who is this gentleman who appears to be anxious to speak to me?', 'The mayor?', 'If you wish to see my passport, sir, my servant will show it to you.', 'No?', 'You wish to welcome me to the place, and to offer your services?', 'I am infinitely flattered.', 'If you have any authority to shorten the performances of your town band, you would be doing me a kindness to exert it.', 'My nerves are irritable, and I dislike music.', 'Where is the landlord?', 'No; I want to see my rooms.', 'I don’t want your arm; I can get upstairs with the help of my stick.', 'Mr<prd> Mayor and Mr<prd> Doctor, we need not detain one another any longer.', 'I wish you good-night."']]
# 41: ['NARRATION', ['Both mayor and doctor looked after the Scotchman as he limped upstairs, and shook their heads together in mute disapproval of him.']]
# 42: ['NARRATION', ['The ladies, as usual, went a step further, and expressed their opinions openly in the plainest words.']]
# 43: ['NARRATION', ['The case under consideration (so far as _they_ were concerned) was the scandalous case of a man who had passed them over entirely without notice.']]
# 44: ['NARRATION', ['Mrs<prd> Mayor could only attribute such an outrage to the native ferocity of a savage.']]
# 45: ['NARRATION', ['Mrs<prd> Doctor took a stronger view still, and considered it as proceeding from the inbred brutality of a hog.']]
# 46: ['NARRATION', ['The hour of waiting for the traveling-carriage wore on, and the creeping night stole up the hillsides softly.']]
# 47: ['NARRATION', ['One by one the stars appeared, and the first lights twinkled in the windows of the inn.']]
# 48: ['NARRATION', ['As the darkness came, the last idlers deserted the square; as the darkness came, the mighty silence of the forest above flowed in on the valley, and strangely and suddenly hushed the lonely little town.']]
# 49: ['NARRATION', ['The hour of waiting wore out, and the figure of the doctor, walking backward and forward anxiously, was still the only living figure left in the square.']]
# 50: ['NARRATION', ['Five minutes, ten minutes, twenty minutes, were counted out by the doctor’s watch, before the first sound came through the night silence to warn him of the approaching carriage.']]

# %%
# alphabets= "([A-Za-z])"
# prefixes = "(Mr|St|Mrs|Ms|Dr)[.]"
# suffixes = "(Inc|Ltd|Jr|Sr|Co)"
# starters = "(Mr|Mrs|Ms|Dr|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever)"
# acronyms = "([A-Z][.][A-Z][.](?:[A-Z][.])?)"
# websites = "[.](com|net|org|io|gov)"

# def split_into_sentences(text):
#     text = " " + text + "  "
#     text = text.replace("\n"," ")
#     text = text.replace("\r"," ")
#     text = re.sub('\s+',' ', text)
#     text = re.sub('[“”]', '"', text)
#     text = re.sub(prefixes,"\\1<prd>",text)
#     text = re.sub(websites,"<prd>\\1",text)
#     if "Ph.D" in text: text = text.replace("Ph.D.","Ph<prd>D<prd>")
#     text = re.sub("\s" + alphabets + "[.] "," \\1<prd> ",text)
#     text = re.sub(acronyms+" "+starters,"\\1<stop> \\2",text)
#     text = re.sub(alphabets + "[.]" + alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>\\3<prd>",text)
#     text = re.sub(alphabets + "[.]" + alphabets + "[.]","\\1<prd>\\2<prd>",text)
#     text = re.sub(" "+suffixes+"[.] "+starters," \\1<stop> \\2",text)
#     text = re.sub(" "+suffixes+"[.]"," \\1<prd>",text)
#     text = re.sub(" " + alphabets + "[.]"," \\1<prd>",text)
#     if "”" in text: text = text.replace(".”","”.")
#     if "\"" in text: text = text.replace(".\"","\".")
#     if "!" in text: text = text.replace("!\"","\"!")
#     if "?" in text: text = text.replace("?\"","\"?")
#     text = text.replace(".",".<stop>")
#     text = text.replace("?","?<stop>")
#     text = text.replace("!","!<stop>")
#     text = text.replace("<prd>",".")
#     sentences = text.split("<stop>")
#     sentences = sentences[:-1]
#     sentences = [s.strip() for s in sentences]
#     return sentences

# %%
# clean_text2 = split_into_sentences(dirty_text)
# print(len(clean_text2))
# for position, sent in enumerate(reversed(clean_text2)):
#     print(position)
#     print(sent)
#     if position == 20:
#         break
    
# # print(len(clean_text2))
# # print(clean_text2[:10])
