# %%
path_to_newspapers = '../../data/corpora/newspapers_test/'
newspaper_test = 'newspaper_test.txt'

# %%
# Imports
import codecs
from nltk.tokenize import sent_tokenize
import re
import spacy
import unicodedata

# %%
regex_expressions = {"initials": r"\b([A-Z][.](\s)?)+", "prefixes": r"(Mr|St|Mrs|Ms|Dr|Esq|Sec|Secretar)[.]",\
                     "addresses": "", "dates": "", "line_break": r"¬\n", "space": r"/s",\
                     "dashes": r"[-]+", "quote_marks": r"(“|”)", \
                     "months_abrv": r"(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[.](\s*(\d{1,2})(,|\.)?)?(\s*\d+)?",\
                     "pennies": r"(\d+[.]?\s*)[d][.]", "months_and_years": r"\d{1,2}[.]\s*(\d{4})"}

# %%
# strip all accented characters:
def strip_accents(text):
    text = unicodedata.normalize('NFD', text).encode('ascii', 'ignore').decode("utf-8")
    return str(text)

def process_periods(text):
    # no matchobj needed since this is only called in other processing functions
    text = re.sub(r"[.]","<prd>", text)
    return text

def process_periods_to_commas(matchobj):
    text = matchobj.group(0)
    text = re.sub(r"[.]", ",", text)
    return text

# processing functions for regex calls in preprocess_text() function
# process initials for regex, and return a format that we can identify
def process_initials(matchobj):
    text = matchobj.group(0)
    text = process_periods(text)
    text = re.sub(r"\s*", "", text)
    text = text + " "
    return text

def process_months_abrv(matchobj):
    text = matchobj.group(0)
    text = process_periods(text)
    # text = " <date>"+text+"<date> "
    return text

def process_pennies(matchobj):
    text = matchobj.group(0)
    text = re.sub(r"d[.]?","pennies", text)
    text = process_periods(text)
    return text

# combine it together
def preprocess_text(text):
    # remove all the line breaks created by newspaper processor
    text = re.sub(regex_expressions["line_break"],"", text)
    # marking initials:
    text = re.sub(regex_expressions["initials"], process_initials, text)
    # process titles:
    text = re.sub(regex_expressions["prefixes"],"\\1<prd>", text, flags=re.IGNORECASE)
    # process month abbreviations:
    text = re.sub(regex_expressions["months_abrv"], process_months_abrv, text, flags=re.IGNORECASE)
    # process instances of months [period] year:
    text = re.sub(regex_expressions["months_and_years"], process_periods_to_commas, text)
    # process instances of "No."
    text = re.sub(r"(No|Nos)[.]","number", text, flags=re.IGNORECASE)
    # strip all dashes:
    text = re.sub(regex_expressions["dashes"], " ", text)
    # transform all quotes to ' " ':
    text = re.sub(regex_expressions["quote_marks"], '"', text)
    # strip all pennies "XX d." in the text:
    text = re.sub(regex_expressions["pennies"], process_pennies, text)
    # strip all accents from the text:
    text = strip_accents(text)
    return text

# %%
def clean_tokenized_sent(sent):
    # removing newline notations
    clean_sent = re.sub('\n', ' ', sent)
    clean_sent = re.sub('\r', ' ', clean_sent)
    # transforming multiple spaces to one space
    clean_sent = re.sub('\s+',' ', clean_sent)
    split_sentence = clean_sent.split()
    
    # transform all the words that are completely uppercase to lowercase
    for index, word in enumerate(split_sentence):
        if (word.isupper()):
            new_word = word.lower()
            split_sentence[index] = new_word
    clean_sent = " ".join(split_sentence)
    
    # put back the periods:
    clean_sent = re.sub("<prd>", ".", clean_sent)
    # clean_sent = clean_sent.lower()
    return clean_sent


def clean_tokenized_list(sent_list):
    cleaned_tokenized_sentences = []
    for sent in sent_list:
        clean_set = clean_tokenized_sent(sent)
        cleaned_tokenized_sentences.append(clean_set)
    return cleaned_tokenized_sentences

# %%
with codecs.open(path_to_newspapers + newspaper_test, 'r', encoding='utf-8', errors="ignore") as raw_text:
    dirty_text = raw_text.read()

# print(dirty_text[:6000])

# %%
preprocessed_text = preprocess_text(dirty_text)
# print(preprocessed_text)

# %%
tokenized_sentences = sent_tokenize(preprocessed_text)
cleaned_tokenized_sentences = clean_tokenized_list(tokenized_sentences)

# %%
print(cleaned_tokenized_sentences[:10])
# Out:
# ['afe F.E. write immediately.', 'In London de vue de are 1 himney top.', 'E.E.F. , alive, weil, and at Hythe.', 'a Happy New Year to you sil.', 'ames.', 'Dear James, pray send to the last address, posible, letters, of great important three from your ever, and most affectionate william, he Overseers of the Parish of Grately.', 'Hants, acknowledge the receptola bankoi england B.F. note for 25, number e with 3 under 82.60, from K. Alas, no improvement since last year.', 'i am still lingering on the brink of the precipice, not witusta ling Stick No Bus and all the kind advice which was the given.', 'a happy no year to you.', 'marianne V. to C.S.V. no letter has been reeived.']

# %%
# POS try:
# first loading english language support

# faster but less accurate model:
# nlp = spacy.load("en_core_web_sm")

# slower but more accurate model:
# download it first
# !python -m spacy download en_core_web_lg

nlp = spacy.load("en_core_web_lg")

def get_pos_counts_from_tagged_sentence(analyzed_sent):
    pos_counts = []
    pos_counts_raw = analyzed_sent.count_by(spacy.attrs.IDS['POS'])
    for pos, count in pos_counts_raw.items():
        tag = analyzed_sent.vocab[pos].text
        pos_count = (tag, count)
        pos_counts.append(pos_count)
    # return a list of pos_counts
    return pos_counts

def pos_tag_sentence(sent):
    tagged_sentence = []
    analyzed_sent = nlp(sent, disable = ['ner'])
    # getting the complete tokenized sentence
    for token in analyzed_sent:
        tagged_word = (token, token.pos_)
        tagged_sentence.append(tagged_word)
    pos_counts = get_pos_counts_from_tagged_sentence(analyzed_sent)
    # return a tuple of both
    return (tagged_sentence, pos_counts)

# %%
def pos_tag_list_of_sentences(list_of_cleaned_sentences):
    pos_tagged_text = []
    for sent in list_of_cleaned_sentences:
        tagged_sent = pos_tag_sentence(sent)
        pos_tagged_text.append(tagged_sent)
        
    return pos_tagged_text

# %%
def get_total_pos_counts(list_of_pos_counts):
    for index, pos_counts in enumerate(list_of_pos_counts):
        for tag, count in pos_counts:
            print(tag)
            print(count)
        if index >= 10:
            break

# %%
 tagged_sentence = pos_tag_list_of_sentences(cleaned_tokenized_sentences)

# %%
print(tagged_sentence[0][1])
# Out:
# [('PROPN', 2), ('VERB', 1), ('ADV', 1), ('PUNCT', 1)]

# %%
spacy.explain('X')
# Out:
# 'other'

# %%
print(dirty_text)

# %%
for index, sent in enumerate(cleaned_tokenized_sentences):
    if index <= 50:
        tagged_sentence, pos_counts = pos_tag_sentence(sent)
        print(index, end=": ")
        print(sent)
        print(tagged_sentence)
        print(pos_counts, end="\n\n")
# Out:
# 0: afe F.E. write immediately.
# [(afe, 'PROPN'), (F.E., 'PROPN'), (write, 'VERB'), (immediately, 'ADV'), (., 'PUNCT')]
# [('PROPN', 2), ('VERB', 1), ('ADV', 1), ('PUNCT', 1)]
#
# 1: In London de vue de are 1 himney top.
# [(In, 'ADP'), (London, 'PROPN'), (de, 'X'), (vue, 'X'), (de, 'X'), (are, 'AUX'), (1, 'NUM'), (himney, 'NOUN'), (top, 'NOUN'), (., 'PUNCT')]
# [('ADP', 1), ('PROPN', 1), ('X', 3), ('AUX', 1), ('NUM', 1), ('NOUN', 2), ('PUNCT', 1)]
#
# 2: E.E.F. , alive, weil, and at Hythe.
# [(E.E.F., 'PROPN'), (,, 'PUNCT'), (alive, 'ADJ'), (,, 'PUNCT'), (weil, 'PROPN'), (,, 'PUNCT'), (and, 'CCONJ'), (at, 'ADP'), (Hythe, 'PROPN'), (., 'PUNCT')]
# [('PROPN', 3), ('PUNCT', 4), ('ADJ', 1), ('CCONJ', 1), ('ADP', 1)]
#
# 3: a Happy New Year to you sil.
# [(a, 'DET'), (Happy, 'PROPN'), (New, 'PROPN'), (Year, 'PROPN'), (to, 'ADP'), (you, 'PRON'), (sil, 'NOUN'), (., 'PUNCT')]
# [('DET', 1), ('PROPN', 3), ('ADP', 1), ('PRON', 1), ('NOUN', 1), ('PUNCT', 1)]
#
# 4: ames.
# [(ames, 'PROPN'), (., 'PUNCT')]
# [('PROPN', 1), ('PUNCT', 1)]
#
# 5: Dear James, pray send to the last address, posible, letters, of great important three from your ever, and most affectionate william, he Overseers of the Parish of Grately.
# [(Dear, 'ADJ'), (James, 'PROPN'), (,, 'PUNCT'), (pray, 'AUX'), (send, 'VERB'), (to, 'ADP'), (the, 'DET'), (last, 'ADJ'), (address, 'NOUN'), (,, 'PUNCT'), (posible, 'ADJ'), (,, 'PUNCT'), (letters, 'NOUN'), (,, 'PUNCT'), (of, 'ADP'), (great, 'ADJ'), (important, 'ADJ'), (three, 'NUM'), (from, 'ADP'), (your, 'PRON'), (ever, 'ADJ'), (,, 'PUNCT'), (and, 'CCONJ'), (most, 'ADV'), (affectionate, 'ADJ'), (william, 'PROPN'), (,, 'PUNCT'), (he, 'PRON'), (Overseers, 'PROPN'), (of, 'ADP'), (the, 'DET'), (Parish, 'PROPN'), (of, 'ADP'), (Grately, 'PROPN'), (., 'PUNCT')]
# [('ADJ', 7), ('PROPN', 5), ('PUNCT', 7), ('AUX', 1), ('VERB', 1), ('ADP', 5), ('DET', 2), ('NOUN', 2), ('NUM', 1), ('PRON', 2), ('CCONJ', 1), ('ADV', 1)]
#
# 6: Hants, acknowledge the receptola bankoi england B.F. note for 25, number e with 3 under 82.60, from K. Alas, no improvement since last year.
# [(Hants, 'NOUN'), (,, 'PUNCT'), (acknowledge, 'VERB'), (the, 'DET'), (receptola, 'PROPN'), (bankoi, 'PROPN'), (england, 'PROPN'), (B.F., 'PROPN'), (note, 'VERB'), (for, 'ADP'), (25, 'NUM'), (,, 'PUNCT'), (number, 'NOUN'), (e, 'NOUN'), (with, 'ADP'), (3, 'NUM'), (under, 'ADP'), (82.60, 'NUM'), (,, 'PUNCT'), (from, 'ADP'), (K., 'PROPN'), (Alas, 'PROPN'), (,, 'PUNCT'), (no, 'DET'), (improvement, 'NOUN'), (since, 'SCONJ'), (last, 'ADJ'), (year, 'NOUN'), (., 'PUNCT')]
# [('NOUN', 5), ('PUNCT', 5), ('VERB', 2), ('DET', 2), ('PROPN', 6), ('ADP', 4), ('NUM', 3), ('SCONJ', 1), ('ADJ', 1)]
#
# 7: i am still lingering on the brink of the precipice, not witusta ling Stick No Bus and all the kind advice which was the given.
# [(i, 'PRON'), (am, 'AUX'), (still, 'ADV'), (lingering, 'VERB'), (on, 'ADP'), (the, 'DET'), (brink, 'NOUN'), (of, 'ADP'), (the, 'DET'), (precipice, 'NOUN'), (,, 'PUNCT'), (not, 'PART'), (witusta, 'NOUN'), (ling, 'PROPN'), (Stick, 'PROPN'), (No, 'DET'), (Bus, 'PROPN'), (and, 'CCONJ'), (all, 'DET'), (the, 'DET'), (kind, 'ADJ'), (advice, 'NOUN'), (which, 'PRON'), (was, 'AUX'), (the, 'DET'), (given, 'VERB'), (., 'PUNCT')]
# [('PRON', 2), ('AUX', 2), ('ADV', 1), ('VERB', 2), ('ADP', 2), ('DET', 6), ('NOUN', 4), ('PUNCT', 2), ('PART', 1), ('PROPN', 3), ('CCONJ', 1), ('ADJ', 1)]
#
# 8: a happy no year to you.
# [(a, 'DET'), (happy, 'ADJ'), (no, 'DET'), (year, 'NOUN'), (to, 'ADP'), (you, 'PRON'), (., 'PUNCT')]
# [('DET', 2), ('ADJ', 1), ('NOUN', 1), ('ADP', 1), ('PRON', 1), ('PUNCT', 1)]
#
# 9: marianne V. to C.S.V. no letter has been reeived.
# [(marianne, 'PROPN'), (V., 'PROPN'), (to, 'ADP'), (C.S.V., 'PROPN'), (no, 'DET'), (letter, 'NOUN'), (has, 'AUX'), (been, 'AUX'), (reeived, 'VERB'), (., 'PUNCT')]
# [('PROPN', 3), ('ADP', 1), ('DET', 1), ('NOUN', 1), ('AUX', 2), ('VERB', 1), ('PUNCT', 1)]
#
# 10: The want of one is not only painful, but embarrassing to all concerned in the state.
# [(The, 'DET'), (want, 'NOUN'), (of, 'ADP'), (one, 'NUM'), (is, 'AUX'), (not, 'PART'), (only, 'ADV'), (painful, 'ADJ'), (,, 'PUNCT'), (but, 'CCONJ'), (embarrassing, 'VERB'), (to, 'ADP'), (all, 'PRON'), (concerned, 'ADJ'), (in, 'ADP'), (the, 'DET'), (state, 'NOUN'), (., 'PUNCT')]
# [('DET', 2), ('NOUN', 2), ('ADP', 3), ('NUM', 1), ('AUX', 1), ('PART', 1), ('ADV', 1), ('ADJ', 2), ('PUNCT', 2), ('CCONJ', 1), ('VERB', 1), ('PRON', 1)]
#
# 11: These feel it out whose interests were contemplated in your proposition.
# [(These, 'PRON'), (feel, 'VERB'), (it, 'PRON'), (out, 'ADP'), (whose, 'DET'), (interests, 'NOUN'), (were, 'AUX'), (contemplated, 'VERB'), (in, 'ADP'), (your, 'PRON'), (proposition, 'NOUN'), (., 'PUNCT')]
# [('PRON', 3), ('VERB', 2), ('ADP', 2), ('DET', 1), ('NOUN', 2), ('AUX', 1), ('PUNCT', 1)]
#
# 12: Being assured of our love, les nothing prevent the removal of intercourse.
# [(Being, 'AUX'), (assured, 'VERB'), (of, 'ADP'), (our, 'PRON'), (love, 'NOUN'), (,, 'PUNCT'), (les, 'NOUN'), (nothing, 'PRON'), (prevent, 'VERB'), (the, 'DET'), (removal, 'NOUN'), (of, 'ADP'), (intercourse, 'NOUN'), (., 'PUNCT')]
# [('AUX', 1), ('VERB', 2), ('ADP', 2), ('PRON', 2), ('NOUN', 4), ('PUNCT', 2), ('DET', 1)]
#
# 13: i am still in the B.P.L. , and at 400, Broadway.
# [(i, 'PRON'), (am, 'AUX'), (still, 'ADV'), (in, 'ADP'), (the, 'DET'), (B.P.L., 'PROPN'), (,, 'PUNCT'), (and, 'CCONJ'), (at, 'ADP'), (400, 'NUM'), (,, 'PUNCT'), (Broadway, 'PROPN'), (., 'PUNCT')]
# [('PRON', 1), ('AUX', 1), ('ADV', 1), ('ADP', 2), ('DET', 1), ('PROPN', 2), ('PUNCT', 3), ('CCONJ', 1), ('NUM', 1)]
#
# 14: for her liberality anke S. is a stitute female.
# [(for, 'ADP'), (her, 'PRON'), (liberality, 'NOUN'), (anke, 'PROPN'), (S., 'PROPN'), (is, 'AUX'), (a, 'DET'), (stitute, 'PROPN'), (female, 'NOUN'), (., 'PUNCT')]
# [('ADP', 1), ('PRON', 1), ('NOUN', 2), ('PROPN', 3), ('AUX', 1), ('DET', 1), ('PUNCT', 1)]
#
# 15: lodging, to in in supplying in books, for the Crimo Orphan Boys going to B.S. food, at proposed ben du received by Mr. 6. a Pestreet.
# [(lodging, 'NOUN'), (,, 'PUNCT'), (to, 'ADP'), (in, 'ADP'), (in, 'ADP'), (supplying, 'VERB'), (in, 'ADP'), (books, 'NOUN'), (,, 'PUNCT'), (for, 'ADP'), (the, 'DET'), (Crimo, 'PROPN'), (Orphan, 'PROPN'), (Boys, 'PROPN'), (going, 'VERB'), (to, 'ADP'), (B.S., 'PROPN'), (food, 'NOUN'), (,, 'PUNCT'), (at, 'SCONJ'), (proposed, 'VERB'), (ben, 'PROPN'), (du, 'PROPN'), (received, 'VERB'), (by, 'ADP'), (Mr., 'PROPN'), (6, 'NUM'), (., 'PUNCT'), (a, 'DET'), (Pestreet, 'PROPN'), (., 'PUNCT')]
# [('NOUN', 3), ('PUNCT', 5), ('ADP', 7), ('VERB', 4), ('DET', 2), ('PROPN', 8), ('SCONJ', 1), ('NUM', 1)]
#
# 16: We S.W.N.B. It is female Niche Refuge, mit to intended to open this Befuge as originally propose moradable object.
# [(We, 'PRON'), (S.W.N.B., 'PROPN'), (It, 'PRON'), (is, 'AUX'), (female, 'ADJ'), (Niche, 'PROPN'), (Refuge, 'PROPN'), (,, 'PUNCT'), (mit, 'VERB'), (to, 'ADP'), (intended, 'VERB'), (to, 'PART'), (open, 'VERB'), (this, 'DET'), (Befuge, 'PROPN'), (as, 'SCONJ'), (originally, 'ADV'), (propose, 'VERB'), (moradable, 'ADJ'), (object, 'NOUN'), (., 'PUNCT')]
# [('PRON', 2), ('PROPN', 4), ('AUX', 1), ('ADJ', 2), ('PUNCT', 2), ('VERB', 4), ('ADP', 1), ('PART', 1), ('DET', 1), ('SCONJ', 1), ('ADV', 1), ('NOUN', 1)]
#
# 17: scale, when 25 has been cribe have been provided.
# [(scale, 'NOUN'), (,, 'PUNCT'), (when, 'SCONJ'), (25, 'NUM'), (has, 'AUX'), (been, 'AUX'), (cribe, 'NOUN'), (have, 'AUX'), (been, 'AUX'), (provided, 'VERB'), (., 'PUNCT')]
# [('NOUN', 2), ('PUNCT', 2), ('SCONJ', 1), ('NUM', 1), ('AUX', 4), ('VERB', 1)]
#
# 18: entyfive pounds revard.
# [(entyfive, 'PROPN'), (pounds, 'NOUN'), (revard, 'VERB'), (., 'PUNCT')]
# [('PROPN', 1), ('NOUN', 1), ('VERB', 1), ('PUNCT', 1)]
#
# 19: absconded.
# [(absconded, 'VERB'), (., 'PUNCT')]
# [('VERB', 1), ('PUNCT', 1)]
#
# 20: Dec. 10. 1859, from the Tavistock Hotel, Covent garde, with nearly 300, alfred buckman, age about a years, dark salLa complexion, height 5 feet 7 inches, little whiskers, stopping figure, donnast look, buried manner.
# [(Dec., 'PROPN'), (10, 'NUM'), (., 'PUNCT'), (1859, 'NUM'), (,, 'PUNCT'), (from, 'ADP'), (the, 'DET'), (Tavistock, 'PROPN'), (Hotel, 'PROPN'), (,, 'PUNCT'), (Covent, 'PROPN'), (garde, 'X'), (,, 'PUNCT'), (with, 'ADP'), (nearly, 'ADV'), (300, 'NUM'), (,, 'PUNCT'), (alfred, 'PROPN'), (buckman, 'PROPN'), (,, 'PUNCT'), (age, 'NOUN'), (about, 'ADP'), (a, 'DET'), (years, 'NOUN'), (,, 'PUNCT'), (dark, 'ADJ'), (salLa, 'PROPN'), (complexion, 'NOUN'), (,, 'PUNCT'), (height, 'NOUN'), (5, 'NUM'), (feet, 'NOUN'), (7, 'NUM'), (inches, 'NOUN'), (,, 'PUNCT'), (little, 'ADJ'), (whiskers, 'NOUN'), (,, 'PUNCT'), (stopping, 'VERB'), (figure, 'NOUN'), (,, 'PUNCT'), (donnast, 'NOUN'), (look, 'NOUN'), (,, 'PUNCT'), (buried, 'VERB'), (manner, 'NOUN'), (., 'PUNCT')]
# [('PROPN', 7), ('NUM', 5), ('PUNCT', 13), ('ADP', 3), ('DET', 2), ('X', 1), ('ADV', 1), ('NOUN', 11), ('ADJ', 2), ('VERB', 2)]
#
# 21: Dressed in a black short coat, black waistocat, and mixed trousers, black hat (Gibus, maker).
# [(Dressed, 'VERB'), (in, 'ADP'), (a, 'DET'), (black, 'ADJ'), (short, 'ADJ'), (coat, 'NOUN'), (,, 'PUNCT'), (black, 'ADJ'), (waistocat, 'NOUN'), (,, 'PUNCT'), (and, 'CCONJ'), (mixed, 'ADJ'), (trousers, 'NOUN'), (,, 'PUNCT'), (black, 'ADJ'), (hat, 'NOUN'), ((, 'PUNCT'), (Gibus, 'PROPN'), (,, 'PUNCT'), (maker, 'NOUN'), (), 'PUNCT'), (., 'PUNCT')]
# [('VERB', 1), ('ADP', 1), ('DET', 1), ('ADJ', 5), ('NOUN', 5), ('PUNCT', 7), ('CCONJ', 1), ('PROPN', 1)]
#
# 22: The above reward will be paid by Mr. Harrison to any one giving such information as will lead to the apprehension of Alfred Buckman.
# [(The, 'DET'), (above, 'ADJ'), (reward, 'NOUN'), (will, 'AUX'), (be, 'AUX'), (paid, 'VERB'), (by, 'ADP'), (Mr., 'PROPN'), (Harrison, 'PROPN'), (to, 'ADP'), (any, 'DET'), (one, 'NOUN'), (giving, 'VERB'), (such, 'ADJ'), (information, 'NOUN'), (as, 'SCONJ'), (will, 'AUX'), (lead, 'VERB'), (to, 'ADP'), (the, 'DET'), (apprehension, 'NOUN'), (of, 'ADP'), (Alfred, 'PROPN'), (Buckman, 'PROPN'), (., 'PUNCT')]
# [('DET', 3), ('ADJ', 2), ('NOUN', 4), ('AUX', 3), ('VERB', 3), ('ADP', 4), ('PROPN', 4), ('SCONJ', 1), ('PUNCT', 1)]
#
# 23: Information to be given at the Police office, Bostreet.
# [(Information, 'NOUN'), (to, 'PART'), (be, 'AUX'), (given, 'VERB'), (at, 'ADP'), (the, 'DET'), (Police, 'PROPN'), (office, 'NOUN'), (,, 'PUNCT'), (Bostreet, 'PROPN'), (., 'PUNCT')]
# [('NOUN', 2), ('PART', 1), ('AUX', 1), ('VERB', 1), ('ADP', 1), ('DET', 1), ('PROPN', 2), ('PUNCT', 2)]
#
# 24: ost, a pooketbook, with papers, also a 25 bote, number topped.
# [(ost, 'PROPN'), (,, 'PUNCT'), (a, 'DET'), (pooketbook, 'NOUN'), (,, 'PUNCT'), (with, 'ADP'), (papers, 'NOUN'), (,, 'PUNCT'), (also, 'ADV'), (a, 'DET'), (25, 'NUM'), (bote, 'ADJ'), (,, 'PUNCT'), (number, 'NOUN'), (topped, 'VERB'), (., 'PUNCT')]
# [('PROPN', 1), ('PUNCT', 5), ('DET', 2), ('NOUN', 3), ('ADP', 1), ('ADV', 1), ('NUM', 1), ('ADJ', 1), ('VERB', 1)]
#
# 25: one pound renard.
# [(one, 'NUM'), (pound, 'NOUN'), (renard, 'NOUN'), (., 'PUNCT')]
# [('NUM', 1), ('NOUN', 2), ('PUNCT', 1)]
#
# 26: Mr. Field, Beau er buildings, Strand.
# [(Mr., 'PROPN'), (Field, 'PROPN'), (,, 'PUNCT'), (Beau, 'PROPN'), (er, 'INTJ'), (buildings, 'NOUN'), (,, 'PUNCT'), (Strand, 'PROPN'), (., 'PUNCT')]
# [('PROPN', 4), ('PUNCT', 3), ('INTJ', 1), ('NOUN', 1)]
#
# 27: ost, from 16 Queens wate Kensington core, a small bed brown terrier puppy.
# [(ost, 'PROPN'), (,, 'PUNCT'), (from, 'ADP'), (16, 'NUM'), (Queens, 'PROPN'), (wate, 'PROPN'), (Kensington, 'PROPN'), (core, 'NOUN'), (,, 'PUNCT'), (a, 'DET'), (small, 'ADJ'), (bed, 'NOUN'), (brown, 'ADJ'), (terrier, 'NOUN'), (puppy, 'NOUN'), (., 'PUNCT')]
# [('PROPN', 4), ('PUNCT', 3), ('ADP', 1), ('NUM', 1), ('NOUN', 4), ('DET', 1), ('ADJ', 2)]
#
# 28: a revardi which will be given at the above addresOST, at or near the Strand Theatre, on Friday, the but, en engrave gold bracelet, with and two Mr. Roben small diamonds set in it.
# [(a, 'DET'), (revardi, 'PROPN'), (which, 'PRON'), (will, 'AUX'), (be, 'AUX'), (given, 'VERB'), (at, 'ADP'), (the, 'DET'), (above, 'ADJ'), (addresOST, 'PUNCT'), (,, 'PUNCT'), (at, 'ADP'), (or, 'CCONJ'), (near, 'ADP'), (the, 'DET'), (Strand, 'PROPN'), (Theatre, 'PROPN'), (,, 'PUNCT'), (on, 'ADP'), (Friday, 'PROPN'), (,, 'PUNCT'), (the, 'PRON'), (but, 'CCONJ'), (,, 'PUNCT'), (en, 'X'), (engrave, 'VERB'), (gold, 'NOUN'), (bracelet, 'NOUN'), (,, 'PUNCT'), (with, 'ADP'), (and, 'CCONJ'), (two, 'NUM'), (Mr., 'PROPN'), (Roben, 'PROPN'), (small, 'ADJ'), (diamonds, 'NOUN'), (set, 'VERB'), (in, 'ADP'), (it, 'PRON'), (., 'PUNCT')]
# [('DET', 3), ('PROPN', 6), ('PRON', 3), ('AUX', 2), ('VERB', 3), ('ADP', 6), ('ADJ', 2), ('PUNCT', 7), ('CCONJ', 3), ('X', 1), ('NOUN', 3), ('NUM', 1)]
#
# 29: Whoever will library, Edgare road, will receive two pounds renard.
# [(Whoever, 'PRON'), (will, 'AUX'), (library, 'VERB'), (,, 'PUNCT'), (Edgare, 'PROPN'), (road, 'NOUN'), (,, 'PUNCT'), (will, 'AUX'), (receive, 'VERB'), (two, 'NUM'), (pounds, 'NOUN'), (renard, 'NOUN'), (., 'PUNCT')]
# [('PRON', 1), ('AUX', 2), ('VERB', 2), ('PUNCT', 3), ('PROPN', 1), ('NOUN', 3), ('NUM', 1)]
#
# 30: ost, a silver gilt (or gold) enamelled broken), containing a x, it is vieron la pamechanical singing bird.
# [(ost, 'PROPN'), (,, 'PUNCT'), (a, 'DET'), (silver, 'ADJ'), (gilt, 'NOUN'), ((, 'PUNCT'), (or, 'CCONJ'), (gold, 'NOUN'), (), 'PUNCT'), (enamelled, 'VERB'), (broken, 'VERB'), (), 'PUNCT'), (,, 'PUNCT'), (containing, 'VERB'), (a, 'DET'), (x, 'NOUN'), (,, 'PUNCT'), (it, 'PRON'), (is, 'AUX'), (vieron, 'X'), (la, 'DET'), (pamechanical, 'ADJ'), (singing, 'NOUN'), (bird, 'NOUN'), (., 'PUNCT')]
# [('PROPN', 1), ('PUNCT', 7), ('DET', 3), ('ADJ', 2), ('NOUN', 5), ('CCONJ', 1), ('VERB', 3), ('PRON', 1), ('AUX', 1), ('X', 1)]
#
# 31: a handsome revard will be given for any information leading to its recovery, Apply to Mr. Martin, 225, Regent street.
# [(a, 'DET'), (handsome, 'ADJ'), (revard, 'NOUN'), (will, 'AUX'), (be, 'AUX'), (given, 'VERB'), (for, 'ADP'), (any, 'DET'), (information, 'NOUN'), (leading, 'VERB'), (to, 'ADP'), (its, 'PRON'), (recovery, 'NOUN'), (,, 'PUNCT'), (Apply, 'VERB'), (to, 'ADP'), (Mr., 'PROPN'), (Martin, 'PROPN'), (,, 'PUNCT'), (225, 'NUM'), (,, 'PUNCT'), (Regent, 'PROPN'), (street, 'NOUN'), (., 'PUNCT')]
# [('DET', 2), ('ADJ', 1), ('NOUN', 4), ('AUX', 2), ('VERB', 3), ('ADP', 3), ('PRON', 1), ('PUNCT', 4), ('PROPN', 3), ('NUM', 1)]
#
# 32: ost, on the 30th December, a sealskin muff, either in going from the London in Rooms, Flotteet, to Waterloo bridge Station, or from thence to Epitaux, under the Colonhoever will bring it to the latter adres shall nade, 3 Pall receive thirty shillings reward.
# [(ost, 'PROPN'), (,, 'PUNCT'), (on, 'ADP'), (the, 'DET'), (30th, 'ADJ'), (December, 'PROPN'), (,, 'PUNCT'), (a, 'DET'), (sealskin, 'NOUN'), (muff, 'NOUN'), (,, 'PUNCT'), (either, 'CCONJ'), (in, 'ADP'), (going, 'VERB'), (from, 'ADP'), (the, 'DET'), (London, 'PROPN'), (in, 'ADP'), (Rooms, 'PROPN'), (,, 'PUNCT'), (Flotteet, 'PROPN'), (,, 'PUNCT'), (to, 'ADP'), (Waterloo, 'PROPN'), (bridge, 'PROPN'), (Station, 'PROPN'), (,, 'PUNCT'), (or, 'CCONJ'), (from, 'ADP'), (thence, 'NOUN'), (to, 'ADP'), (Epitaux, 'PROPN'), (,, 'PUNCT'), (under, 'ADP'), (the, 'DET'), (Colonhoever, 'PROPN'), (will, 'AUX'), (bring, 'VERB'), (it, 'PRON'), (to, 'ADP'), (the, 'DET'), (latter, 'ADJ'), (adres, 'PROPN'), (shall, 'AUX'), (nade, 'VERB'), (,, 'PUNCT'), (3, 'NUM'), (Pall, 'PROPN'), (receive, 'VERB'), (thirty, 'NUM'), (shillings, 'NOUN'), (reward, 'NOUN'), (., 'PUNCT')]
# [('PROPN', 12), ('PUNCT', 9), ('ADP', 9), ('DET', 5), ('ADJ', 2), ('NOUN', 5), ('CCONJ', 2), ('VERB', 4), ('AUX', 2), ('PRON', 1), ('NUM', 2)]
#
# 33: nne pound revard.
# [(nne, 'PROPN'), (pound, 'NOUN'), (revard, 'NOUN'), (., 'PUNCT')]
# [('PROPN', 1), ('NOUN', 2), ('PUNCT', 1)]
#
# 34: left in a cab on the morning of the Schult, in the King's road, Chelsen, an account book bound in blue morocco, lettered "Tradesen Accounts."
# [(left, 'VERB'), (in, 'ADP'), (a, 'DET'), (cab, 'NOUN'), (on, 'ADP'), (the, 'DET'), (morning, 'NOUN'), (of, 'ADP'), (the, 'DET'), (Schult, 'PROPN'), (,, 'PUNCT'), (in, 'ADP'), (the, 'DET'), (King, 'PROPN'), ('s, 'PART'), (road, 'NOUN'), (,, 'PUNCT'), (Chelsen, 'PROPN'), (,, 'PUNCT'), (an, 'DET'), (account, 'NOUN'), (book, 'NOUN'), (bound, 'VERB'), (in, 'ADP'), (blue, 'ADJ'), (morocco, 'PROPN'), (,, 'PUNCT'), (lettered, 'ADJ'), (", 'PUNCT'), (Tradesen, 'PROPN'), (Accounts, 'PROPN'), (., 'PUNCT'), (", 'PUNCT')]
# [('VERB', 2), ('ADP', 5), ('DET', 5), ('NOUN', 5), ('PROPN', 6), ('PUNCT', 7), ('PART', 1), ('ADJ', 2)]
#
# 35: To be brought to Mr. Ambler, 1, Oakloy square.
# [(To, 'PART'), (be, 'AUX'), (brought, 'VERB'), (to, 'ADP'), (Mr., 'PROPN'), (Ambler, 'PROPN'), (,, 'PUNCT'), (1, 'NUM'), (,, 'PUNCT'), (Oakloy, 'PROPN'), (square, 'NOUN'), (., 'PUNCT')]
# [('PART', 1), ('AUX', 1), ('VERB', 1), ('ADP', 1), ('PROPN', 3), ('PUNCT', 3), ('NUM', 1), ('NOUN', 1)]
#
# 36: Chelse.
# [(Chelse, 'PROPN'), (., 'PUNCT')]
# [('PROPN', 1), ('PUNCT', 1)]
#
# 37: nne pound revard.
# [(nne, 'PROPN'), (pound, 'NOUN'), (revard, 'NOUN'), (., 'PUNCT')]
# [('PROPN', 1), ('NOUN', 2), ('PUNCT', 1)]
#
# 38: lost, on Wednesday black opera glasses, in a shut up leather case, with gilt clas.
# [(lost, 'VERB'), (,, 'PUNCT'), (on, 'ADP'), (Wednesday, 'PROPN'), (black, 'ADJ'), (opera, 'NOUN'), (glasses, 'NOUN'), (,, 'PUNCT'), (in, 'ADP'), (a, 'DET'), (shut, 'ADJ'), (up, 'ADP'), (leather, 'NOUN'), (case, 'NOUN'), (,, 'PUNCT'), (with, 'ADP'), (gilt, 'NOUN'), (clas, 'NOUN'), (., 'PUNCT')]
# [('VERB', 1), ('PUNCT', 4), ('ADP', 4), ('PROPN', 1), ('ADJ', 2), ('NOUN', 6), ('DET', 1)]
#
# 39: Whoever will bring the same to 69, Harley Street, shall receive the above reward.
# [(Whoever, 'PRON'), (will, 'AUX'), (bring, 'VERB'), (the, 'DET'), (same, 'ADJ'), (to, 'ADP'), (69, 'NUM'), (,, 'PUNCT'), (Harley, 'PROPN'), (Street, 'PROPN'), (,, 'PUNCT'), (shall, 'AUX'), (receive, 'VERB'), (the, 'DET'), (above, 'ADJ'), (reward, 'NOUN'), (., 'PUNCT')]
# [('PRON', 1), ('AUX', 2), ('VERB', 2), ('DET', 2), ('ADJ', 2), ('ADP', 1), ('NUM', 1), ('PUNCT', 3), ('PROPN', 2), ('NOUN', 1)]
#
# 40: ve guineas renard.
# [(ve, 'VERB'), (guineas, 'NOUN'), (renard, 'ADJ'), (., 'PUNCT')]
# [('VERB', 1), ('NOUN', 1), ('ADJ', 1), ('PUNCT', 1)]
#
# 41: lost, a ladis gold watch, on Tuesday, 19thult, between Russell square and Queen's Elm, Brompton, number 20,893, of a lever construction and chronometer balance ; maker, Bennett.
# [(lost, 'VERB'), (,, 'PUNCT'), (a, 'DET'), (ladis, 'ADJ'), (gold, 'NOUN'), (watch, 'NOUN'), (,, 'PUNCT'), (on, 'ADP'), (Tuesday, 'PROPN'), (,, 'PUNCT'), (19thult, 'NUM'), (,, 'PUNCT'), (between, 'ADP'), (Russell, 'PROPN'), (square, 'PROPN'), (and, 'CCONJ'), (Queen, 'PROPN'), ('s, 'PART'), (Elm, 'PROPN'), (,, 'PUNCT'), (Brompton, 'PROPN'), (,, 'PUNCT'), (number, 'NOUN'), (20,893, 'NUM'), (,, 'PUNCT'), (of, 'ADP'), (a, 'DET'), (lever, 'NOUN'), (construction, 'NOUN'), (and, 'CCONJ'), (chronometer, 'NOUN'), (balance, 'NOUN'), (;, 'PUNCT'), (maker, 'NOUN'), (,, 'PUNCT'), (Bennett, 'PROPN'), (., 'PUNCT')]
# [('VERB', 1), ('PUNCT', 10), ('DET', 2), ('ADJ', 1), ('NOUN', 8), ('ADP', 3), ('PROPN', 7), ('NUM', 2), ('CCONJ', 2), ('PART', 1)]
#
# 42: To be brought to the watch manufactory, 65, Cheapide.
# [(To, 'PART'), (be, 'AUX'), (brought, 'VERB'), (to, 'ADP'), (the, 'DET'), (watch, 'NOUN'), (manufactory, 'NOUN'), (,, 'PUNCT'), (65, 'NUM'), (,, 'PUNCT'), (Cheapide, 'PROPN'), (., 'PUNCT')]
# [('PART', 1), ('AUX', 1), ('VERB', 1), ('ADP', 1), ('DET', 1), ('NOUN', 2), ('PUNCT', 3), ('NUM', 1), ('PROPN', 1)]
#
# 43: en shillings renard.
# [(en, 'ADP'), (shillings, 'NOUN'), (renard, 'PROPN'), (., 'PUNCT')]
# [('ADP', 1), ('NOUN', 1), ('PROPN', 1), ('PUNCT', 1)]
#
# 44: laft, in a cab, which took a lady from Tottenbancourt road to Avenue road, on Wednesday, the Stb.
# [(laft, 'PROPN'), (,, 'PUNCT'), (in, 'ADP'), (a, 'DET'), (cab, 'NOUN'), (,, 'PUNCT'), (which, 'PRON'), (took, 'VERB'), (a, 'DET'), (lady, 'NOUN'), (from, 'ADP'), (Tottenbancourt, 'PROPN'), (road, 'NOUN'), (to, 'ADP'), (Avenue, 'PROPN'), (road, 'NOUN'), (,, 'PUNCT'), (on, 'ADP'), (Wednesday, 'PROPN'), (,, 'PUNCT'), (the, 'DET'), (Stb, 'PROPN'), (., 'PUNCT')]
# [('PROPN', 5), ('PUNCT', 5), ('ADP', 4), ('DET', 3), ('NOUN', 4), ('PRON', 1), ('VERB', 1)]
#
# 45: a small leathern bag, containing lettera pencil case, cheque, &c. To be brought to Mr. Ross, 248, High Holborn.
# [(a, 'DET'), (small, 'ADJ'), (leathern, 'ADJ'), (bag, 'NOUN'), (,, 'PUNCT'), (containing, 'VERB'), (lettera, 'NOUN'), (pencil, 'NOUN'), (case, 'NOUN'), (,, 'PUNCT'), (cheque, 'NOUN'), (,, 'PUNCT'), (&, 'CCONJ'), (c., 'PROPN'), (To, 'PART'), (be, 'AUX'), (brought, 'VERB'), (to, 'ADP'), (Mr., 'PROPN'), (Ross, 'PROPN'), (,, 'PUNCT'), (248, 'NUM'), (,, 'PUNCT'), (High, 'PROPN'), (Holborn, 'PROPN'), (., 'PUNCT')]
# [('DET', 1), ('ADJ', 2), ('NOUN', 5), ('PUNCT', 6), ('VERB', 2), ('CCONJ', 1), ('PROPN', 5), ('PART', 1), ('AUX', 1), ('ADP', 1), ('NUM', 1)]
#
# 46: The payment of the chaque has been stopped.
# [(The, 'DET'), (payment, 'NOUN'), (of, 'ADP'), (the, 'DET'), (chaque, 'NOUN'), (has, 'AUX'), (been, 'AUX'), (stopped, 'VERB'), (., 'PUNCT')]
# [('DET', 2), ('NOUN', 2), ('ADP', 1), ('AUX', 2), ('VERB', 1), ('PUNCT', 1)]
#
# 47: ree pourds renard.lost, at Graveend about the end of June last, on landing from Meere Green ship Trafalgar, a gun, in wooden cace, with the name of J. Deacon, Royal Regiment," on a bras plate on the lid of the case.
# [(ree, 'PROPN'), (pourds, 'NOUN'), (renard.lost, 'VERB'), (,, 'PUNCT'), (at, 'ADP'), (Graveend, 'PROPN'), (about, 'ADP'), (the, 'DET'), (end, 'NOUN'), (of, 'ADP'), (June, 'PROPN'), (last, 'ADJ'), (,, 'PUNCT'), (on, 'ADP'), (landing, 'VERB'), (from, 'ADP'), (Meere, 'PROPN'), (Green, 'PROPN'), (ship, 'NOUN'), (Trafalgar, 'PROPN'), (,, 'PUNCT'), (a, 'DET'), (gun, 'NOUN'), (,, 'PUNCT'), (in, 'ADP'), (wooden, 'ADJ'), (cace, 'NOUN'), (,, 'PUNCT'), (with, 'ADP'), (the, 'DET'), (name, 'NOUN'), (of, 'ADP'), (J., 'PROPN'), (Deacon, 'PROPN'), (,, 'PUNCT'), (Royal, 'PROPN'), (Regiment, 'PROPN'), (,, 'PUNCT'), (", 'PUNCT'), (on, 'ADP'), (a, 'DET'), (bras, 'NOUN'), (plate, 'NOUN'), (on, 'ADP'), (the, 'DET'), (lid, 'NOUN'), (of, 'ADP'), (the, 'DET'), (case, 'NOUN'), (., 'PUNCT')]
# [('PROPN', 10), ('NOUN', 10), ('VERB', 2), ('PUNCT', 9), ('ADP', 11), ('DET', 6), ('ADJ', 2)]
#
# 48: The above reward will be paid to anyone restoring the gun to es.
# [(The, 'DET'), (above, 'ADJ'), (reward, 'NOUN'), (will, 'AUX'), (be, 'AUX'), (paid, 'VERB'), (to, 'ADP'), (anyone, 'PRON'), (restoring, 'VERB'), (the, 'DET'), (gun, 'NOUN'), (to, 'PART'), (es, 'VERB'), (., 'PUNCT')]
# [('DET', 2), ('ADJ', 1), ('NOUN', 2), ('AUX', 2), ('VERB', 3), ('ADP', 1), ('PRON', 1), ('PART', 1), ('PUNCT', 1)]
#
# 49: Everest and Son, Royal Exchange.
# [(Everest, 'PROPN'), (and, 'CCONJ'), (Son, 'PROPN'), (,, 'PUNCT'), (Royal, 'PROPN'), (Exchange, 'PROPN'), (., 'PUNCT')]
# [('PROPN', 4), ('CCONJ', 1), ('PUNCT', 2)]
#
# 50: ve pounds revard.
# [(ve, 'AUX'), (pounds, 'NOUN'), (revard, 'VERB'), (., 'PUNCT')]
# [('AUX', 1), ('NOUN', 1), ('VERB', 1), ('PUNCT', 1)]
